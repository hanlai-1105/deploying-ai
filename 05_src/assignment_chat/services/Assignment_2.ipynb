# %%
import requests

def get_weather(city: str) -> str:
    try:
        url = f"https://wttr.in/{city}?format=j1"
        response = requests.get(url)

        if response.status_code != 200:
            return "Sorry, I couldn't fetch the weather."

        data = response.json()
        current = data["current_condition"][0]

        temperature = current["temp_C"]
        description = current["weatherDesc"][0]["value"]

        return f"In {city}, it is currently {description} with a temperature of {temperature}°C."

    except Exception as e:
        return "There was an issue retrieving weather data."

# %%
from API_service import get_weather
print(get_weather("Toronto"))
# Out:
# In Toronto, it is currently Overcast with a temperature of 0°C.

# %%
from semantic_service import semantic_search
print(semantic_search("What is machine learning?"))
# Out:
# Here is what I found:
# Machine learning allows computers to learn patterns from data.
# Deep learning is a subset of machine learning using neural networks.

# %%
from tool_service import create_study_plan
print(create_study_plan("Python programming", 14))
# Out:
# 14-day study plan for Python programming:
#
# Day 1: Python basics and syntax
#   • Study theory
#   • Practice exercises
#   • Review notes
#
# Day 2: Control flow and functions
#   • Study theory
#   • Practice exercises
#   • Review notes
#
# Day 3: Data structures (lists, dicts, sets)
#   • Study theory
#   • Practice exercises
#   • Review notes
#
# Day 4: File handling and exceptions
#   • Study theory
#   • Practice exercises
#   • Review notes
#
# Day 5: Object-oriented programming
#   • Study theory
#   • Practice exercises
#   • Review notes
#
# Day 6: Libraries (NumPy, pandas)
#   • Study theory
#   • Practice exercises
#   • Review notes
#
# Day 7: Mini project
#   • Study theory
#   • Practice exercises
#   • Review notes
#
# Day 8: Python basics and syntax
#   • Study theory
#   • Practice exercises
#   • Review notes
#
# Day 9: Control flow and functions
#   • Study theory
#   • Practice exercises
#   • Review notes
#
# Day 10: Data structures (lists, dicts, sets)
# ...
